# %%
from turtle import *
shape('turtle')
for a in range(4):
    forward(100)
    left(90)





















done()

# %%
from turtle import *
fillcolor('sea green')
shape('turtle')
begin_fill()
for a in range(4):
    forward(100)
    left(90)
end_fill()














done()

# %%
from turtle import *
circle(50)
done()

# %%
from turtle import *
fillcolor('yellow')
begin_fill()
for a in range(4):
    forward(100)
    left(90)
end_fill()
penup()
goto(50,150)
pendown()
right(45)
forward(75)
backward(75)
left(-90)
forward(75)
penup()
goto(50,50)
pendown()
right(45)
for a in range(4):
    forward(30)
    left(90)
right(90)
for a in range(4):
    forward(30)
    left(90)
right(90)
for a in range(4):
    forward(30)
    left(90)
right(90)
for a in range(4):
    forward(30)
    left(90)


done()

# %%
from turtle import * 
import random as rnd
speed(0.3)
bgcolor('green')
list = ['red','green','blue']
for a in range(999999999999999999999999999999999999999999999):
    rand = rnd.choice(list)
    fillcolor(rand)
    begin_fill()
    circle(50)
    rt(15)
    end_fill()
